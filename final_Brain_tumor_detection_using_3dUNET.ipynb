# %%
import os

# %run "/content/drive/MyDrive/3D UNET.ipynb"
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# from inception_unet import bulid_model
# Out:
# (None, 256, 256, 1)

# %% [markdown]
# ## Dice loss

# %%
def dice_coeff(y_true,y_hat):
    smooth = 1e-15
    y_true = tf.keras.layers.Flatten()(y_true)
    y_hat = tf.keras.layers.Flatten()(y_hat)
    intersection = tf.reduce_sum(y_hat*y_true)
    return (2*intersection + smooth)/(tf.reduce_sum(y_true) + tf.reduce_sum(y_hat))

# %%
def dice_loss(y_true,y_hat):
    return 1 - dice_coeff(y_true,y_hat)

# %%
path = "/content/drive/MyDrive/mm"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
epochs = 100
batch_size = 16
lr = 1e-3
W, H =256,256

# %%
def load_dataset(path, split=0.2):
    images = sorted(glob(os.path.join(path, "images", "*.png")))
    masks = sorted(glob(os.path.join(path, "masks", "*.png")))

    split_size = int(len(images) * split)

    if len(images) < 3 or len(masks) < 3:
        raise ValueError("Insufficient data for splitting. Make sure you have at least three samples.")
    train_x, test_x, train_y, test_y = train_test_split(images[:3064], masks, test_size=split, random_state=42)
    train_x, valid_x, train_y, valid_y = train_test_split(train_x, train_y, test_size=split, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (h, w)
    x = cv2.resize(x, (W, H))   ## (h, w)
    x = x / 255.0               ## (h, w)
    x = x.astype(np.float32)    ## (h, w)
    x = np.expand_dims(x, axis=-1)## (h, w, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %%
(train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(path)
train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

# %%
test_dataset = tf_dataset(test_x, test_y, batch=batch_size)

# %%
import matplotlib.pyplot as plt
import numpy as np



# Create a tf.data.Dataset for visualization
visualization_dataset = tf_dataset(train_x[:3], train_y[:3], batch=3)

# Iterate through the dataset and visualize images and masks
for batch in visualization_dataset:
    images, masks = batch
    for i in range(images.shape[0]):
        plt.figure(figsize=(12, 6))

        # Visualize the original image
        plt.subplot(1, 2, 1)
        plt.imshow(images[i])
        plt.title("Original Image")
        plt.axis("off")

        # Visualize the corresponding mask
        plt.subplot(1, 2, 2)
        plt.imshow(np.squeeze(masks[i]), cmap='YlOrRd')  # Assuming masks are grayscale

        plt.title("Mask")
        plt.axis("off")

        plt.show()

# %% [markdown]
# ## Model
# **bold text**

# %%
from tensorflow.keras.metrics import Recall, Precision,F1Score


model = bulid_model()
# Define your metrics
recall = Recall(name='recall')
precision = Precision(name='precision')

# Compile your model
model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coeff, 'accuracy', recall, precision])
# Out:
# (None, 256, 256, 1)

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
    EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False),
]

# %%
model.fit(
        train_dataset,
        epochs=epochs,
        validation_data=valid_dataset,
        callbacks=callbacks
    )
# Out:
# Epoch 1/100
# 123/123 [==============================] - 108s 877ms/step - loss: 0.5032 - dice_coeff: 0.4964 - accuracy: 0.9834 - recall: 0.4693 - precision: 0.5387 - val_loss: 0.6449 - val_dice_coeff: 0.3551 - val_accuracy: 0.9839 - val_recall: 0.2473 - val_precision: 0.6016 - lr: 0.0010
# Epoch 2/100
# 123/123 [==============================] - 112s 912ms/step - loss: 0.4897 - dice_coeff: 0.5101 - accuracy: 0.9838 - recall: 0.4821 - precision: 0.5522 - val_loss: 0.6864 - val_dice_coeff: 0.3138 - val_accuracy: 0.9839 - val_recall: 0.2040 - val_precision: 0.6275 - lr: 0.0010
# Epoch 3/100
# 123/123 [==============================] - 112s 912ms/step - loss: 0.4795 - dice_coeff: 0.5203 - accuracy: 0.9843 - recall: 0.4868 - precision: 0.5717 - val_loss: 0.5501 - val_dice_coeff: 0.4526 - val_accuracy: 0.9824 - val_recall: 0.4096 - val_precision: 0.5076 - lr: 0.0010
# Epoch 4/100
# 123/123 [==============================] - 112s 913ms/step - loss: 0.4726 - dice_coeff: 0.5272 - accuracy: 0.9845 - recall: 0.4933 - precision: 0.5771 - val_loss: 0.5830 - val_dice_coeff: 0.4196 - val_accuracy: 0.9834 - val_recall: 0.3352 - val_precision: 0.5496 - lr: 0.0010
# Epoch 5/100
# 123/123 [==============================] - 112s 912ms/step - loss: 0.4646 - dice_coeff: 0.5349 - accuracy: 0.9848 - recall: 0.4990 - precision: 0.5895 - val_loss: 0.7073 - val_dice_coeff: 0.2929 - val_accuracy: 0.9815 - val_recall: 0.2188 - val_precision: 0.4449 - lr: 0.0010
# Epoch 6/100
# 123/123 [==============================] - 112s 912ms/step - loss: 0.4573 - dice_coeff: 0.5424 - accuracy: 0.9851 - recall: 0.5039 - precision: 0.5991 - val_loss: 0.5820 - val_dice_coeff: 0.4188 - val_accuracy: 0.9770 - val_recall: 0.4761 - val_precision: 0.3818 - lr: 0.0010
# Epoch 7/100
# 123/123 [==============================] - 112s 911ms/step - loss: 0.4448 - dice_coeff: 0.5547 - accuracy: 0.9856 - recall: 0.5118 - precision: 0.6192 - val_loss: 0.5652 - val_dice_coeff: 0.4356 - val_accuracy: 0.9814 - val_recall: 0.4083 - val_precision: 0.4730 - lr: 0.0010
# Epoch 8/100
# 123/123 [==============================] - ETA: 0s - loss: 0.4389 - dice_coeff: 0.5607 - accuracy: 0.9858 - recall: 0.5158 - precision: 0.6253
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 123/123 [==============================] - 112s 912ms/step - loss: 0.4389 - dice_coeff: 0.5607 - accuracy: 0.9858 - recall: 0.5158 - precision: 0.6253 - val_loss: 0.5959 - val_dice_coeff: 0.4053 - val_accuracy: 0.9830 - val_recall: 0.3235 - val_precision: 0.5339 - lr: 0.0010
# Epoch 9/100
# 123/123 [==============================] - 110s 894ms/step - loss: 0.4128 - dice_coeff: 0.5867 - accuracy: 0.9869 - recall: 0.5304 - precision: 0.6701 - val_loss: 0.5978 - val_dice_coeff: 0.4037 - val_accuracy: 0.9849 - val_recall: 0.2836 - val_precision: 0.6729 - lr: 1.0000e-04
# Epoch 10/100
# 123/123 [==============================] - 110s 896ms/step - loss: 0.3923 - dice_coeff: 0.6072 - accuracy: 0.9877 - recall: 0.5401 - precision: 0.7076 - val_loss: 0.5788 - val_dice_coeff: 0.4228 - val_accuracy: 0.9849 - val_recall: 0.3075 - val_precision: 0.6574 - lr: 1.0000e-04
# Epoch 11/100
# 123/123 [==============================] - 112s 913ms/step - loss: 0.3818 - dice_coeff: 0.6177 - accuracy: 0.9880 - recall: 0.5483 - precision: 0.7217 - val_loss: 0.5656 - val_dice_coeff: 0.4360 - val_accuracy: 0.9848 - val_recall: 0.3281 - val_precision: 0.6371 - lr: 1.0000e-04
# Epoch 12/100
# 123/123 [==============================] - 112s 912ms/step - loss: 0.3735 - dice_coeff: 0.6260 - accuracy: 0.9883 - recall: 0.5540 - precision: 0.7339 - val_loss: 0.5645 - val_dice_coeff: 0.4371 - val_accuracy: 0.9847 - val_recall: 0.3315 - val_precision: 0.6302 - lr: 1.0000e-04
# Epoch 13/100
# 123/123 [==============================] - ETA: 0s - loss: 0.3677 - dice_coeff: 0.6319 - accuracy: 0.9885 - recall: 0.5588 - precision: 0.7413
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 123/123 [==============================] - 110s 895ms/step - loss: 0.3677 - dice_coeff: 0.6319 - accuracy: 0.9885 - recall: 0.5588 - precision: 0.7413 - val_loss: 0.5695 - val_dice_coeff: 0.4323 - val_accuracy: 0.9846 - val_recall: 0.3275 - val_precision: 0.6248 - lr: 1.0000e-04
# Epoch 14/100
# 123/123 [==============================] - 112s 912ms/step - loss: 0.3610 - dice_coeff: 0.6385 - accuracy: 0.9888 - recall: 0.5601 - precision: 0.7561 - val_loss: 0.5574 - val_dice_coeff: 0.4443 - val_accuracy: 0.9844 - val_recall: 0.3498 - val_precision: 0.6028 - lr: 1.0000e-05
# Epoch 15/100
# 123/123 [==============================] - 112s 912ms/step - loss: 0.3589 - dice_coeff: 0.6406 - accuracy: 0.9888 - recall: 0.5643 - precision: 0.7549 - val_loss: 0.5568 - val_dice_coeff: 0.4448 - val_accuracy: 0.9843 - val_recall: 0.3523 - val_precision: 0.5983 - lr: 1.0000e-05
# Epoch 16/100
# 123/123 [==============================] - 112s 913ms/step - loss: 0.3577 - dice_coeff: 0.6419 - accuracy: 0.9888 - recall: 0.5654 - precision: 0.7562 - val_loss: 0.5578 - val_dice_coeff: 0.4438 - val_accuracy: 0.9843 - val_recall: 0.3515 - val_precision: 0.5972 - lr: 1.0000e-05
# Epoch 17/100
# 123/123 [==============================] - 112s 913ms/step - loss: 0.3568 - dice_coeff: 0.6428 - accuracy: 0.9889 - recall: 0.5660 - precision: 0.7576 - val_loss: 0.5588 - val_dice_coeff: 0.4428 - val_accuracy: 0.9843 - val_recall: 0.3503 - val_precision: 0.5973 - lr: 1.0000e-05
# Epoch 18/100
# 123/123 [==============================] - ETA: 0s - loss: 0.3560 - dice_coeff: 0.6436 - accuracy: 0.9889 - recall: 0.5666 - precision: 0.7586
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 123/123 [==============================] - 112s 912ms/step - loss: 0.3560 - dice_coeff: 0.6436 - accuracy: 0.9889 - recall: 0.5666 - precision: 0.7586 - val_loss: 0.5595 - val_dice_coeff: 0.4421 - val_accuracy: 0.9843 - val_recall: 0.3497 - val_precision: 0.5966 - lr: 1.0000e-05
# Epoch 19/100
# 123/123 [==============================] - 110s 895ms/step - loss: 0.3549 - dice_coeff: 0.6447 - accuracy: 0.9889 - recall: 0.5661 - precision: 0.7622 - val_loss: 0.5581 - val_dice_coeff: 0.4434 - val_accuracy: 0.9842 - val_recall: 0.3529 - val_precision: 0.5926 - lr: 1.0000e-06
# Epoch 20/100
# 123/123 [==============================] - 110s 895ms/step - loss: 0.3548 - dice_coeff: 0.6448 - accuracy: 0.9889 - recall: 0.5664 - precision: 0.7620 - val_loss: 0.5577 - val_dice_coeff: 0.4438 - val_accuracy: 0.9842 - val_recall: 0.3540 - val_precision: 0.5916 - lr: 1.0000e-06
# Epoch 21/100
# 123/123 [==============================] - 112s 912ms/step - loss: 0.3547 - dice_coeff: 0.6449 - accuracy: 0.9889 - recall: 0.5666 - precision: 0.7619 - val_loss: 0.5577 - val_dice_coeff: 0.4439 - val_accuracy: 0.9842 - val_recall: 0.3542 - val_precision: 0.5911 - lr: 1.0000e-06
# Epoch 22/100
# 123/123 [==============================] - 110s 895ms/step - loss: 0.3546 - dice_coeff: 0.6449 - accuracy: 0.9889 - recall: 0.5668 - precision: 0.7618 - val_loss: 0.5577 - val_dice_coeff: 0.4439 - val_accuracy: 0.9842 - val_recall: 0.3543 - val_precision: 0.5909 - lr: 1.0000e-06
# Epoch 23/100
# 123/123 [==============================] - ETA: 0s - loss: 0.3546 - dice_coeff: 0.6450 - accuracy: 0.9889 - recall: 0.5670 - precision: 0.7618
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 123/123 [==============================] - 110s 895ms/step - loss: 0.3546 - dice_coeff: 0.6450 - accuracy: 0.9889 - recall: 0.5670 - precision: 0.7618 - val_loss: 0.5577 - val_dice_coeff: 0.4438 - val_accuracy: 0.9842 - val_recall: 0.3543 - val_precision: 0.5908 - lr: 1.0000e-06

# %%
history = model.history.history
print(list(history.keys()))
# Out:
# ['loss', 'dice_coeff', 'accuracy', 'recall', 'precision', 'val_loss', 'val_dice_coeff', 'val_accuracy', 'val_recall', 'val_precision', 'lr']

# %%
history = model.history.history  # Access the history attribute

# Create a new figure and plot the training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history['loss'], label='train', color='r')
plt.plot(history['val_loss'], label='validation', color='g')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.show()
print(history.keys())
# Out:
# dict_keys(['loss', 'dice_coeff', 'accuracy', 'recall', 'precision', 'val_loss', 'val_dice_coeff', 'val_accuracy', 'val_recall', 'val_precision', 'lr'])

# %%
result= model.evaluate(test_dataset)

print(f"Test Loss:{result[0]}")
print(f"Test dice coeff:{result[1]}")
print(f"Test Accuarcy:{result[2]*100} %")
print(f"Test Recall: {result[3]}")
print(f"Test Precision: {result[4]}")
f1_score = 2* ((result[3] *result[4]) / (result[4] +result[3]))
print(f"f1score :{f1_score}")
# Out:
# 39/39 [==============================] - 10s 256ms/step - loss: 0.5536 - dice_coeff: 0.4422 - accuracy: 0.9842 - recall: 0.3669 - precision: 0.6036
# Test Loss:0.5535937547683716
# Test dice coeff:0.4422197937965393
# Test Accuarcy:98.4233021736145 %
# Test Recall: 0.366852343082428
# Test Precision: 0.6035875678062439
# f1score :0.456344614479786

# %%
num_samples = 12  # Specify the number of samples you want to visualize

visualization_dataset = valid_dataset.take(num_samples)
plt.figure(figsize=(6, 2*num_samples))
# Assuming valid_dataset provides tuples (image, mask)
for counter, (img_data, true_mask) in enumerate(visualization_dataset):
    # Expand dimensions if necessary (e.g., for grayscale images)
    # true_mask = np.expand_dims(true_mask, -1)

    # Make predictions
    prediction = model.predict(img_data)
    no_of_batch = np.random.randint(0,16,1)
    print(no_of_batch)

    # Plotting
    plt.subplot(num_samples, 3, 3 * counter + 1)
    plt.imshow(img_data[no_of_batch[0]])  # Accessing the first element in the batch
    plt.title("Image")
    plt.axis('off')

    plt.subplot(num_samples, 3, 3 * counter + 2)
    plt.imshow(prediction[no_of_batch[0]])  # Accessing the first element in the batch
    plt.title('Predicted Mask')
    plt.axis('off')

    plt.subplot(num_samples, 3, 3 * counter + 3)
    plt.imshow(true_mask[no_of_batch[0]])  # Assuming true_mask is the ground truth mask
    plt.title('True Mask')
    plt.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 0s 40ms/step
# [11]
# 1/1 [==============================] - 0s 43ms/step
# [10]
# 1/1 [==============================] - 0s 40ms/step
# [6]
# 1/1 [==============================] - 0s 54ms/step
# [8]
# 1/1 [==============================] - 0s 69ms/step
# [3]
# 1/1 [==============================] - 0s 117ms/step
# [2]
# 1/1 [==============================] - 0s 86ms/step
# [10]
# 1/1 [==============================] - 0s 65ms/step
# [7]
# 1/1 [==============================] - 0s 165ms/step
# [14]
# 1/1 [==============================] - 0s 64ms/step
# [11]
# 1/1 [==============================] - 0s 140ms/step
# [3]
# 1/1 [==============================] - 0s 36ms/step
# [12]
